# %%
import pandas as pd

# %%
path = '/Users/theavilla/Documents/github_repos/zoomcamp/homework/module-1/green_tripdata_2019-10.csv'

# %%
df = pd.read_csv(path)
# Out:
# /var/folders/tn/xcbhh5553dq0q02jnpmgv1rh0000gp/T/ipykernel_76285/3280352130.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0       2.0  2019-10-01 00:26:02   2019-10-01 00:39:58                  N
# 1       1.0  2019-10-01 00:18:11   2019-10-01 00:22:38                  N
# 2       1.0  2019-10-01 00:09:31   2019-10-01 00:24:47                  N
# 3       1.0  2019-10-01 00:37:40   2019-10-01 00:41:49                  N
# 4       2.0  2019-10-01 00:08:13   2019-10-01 00:17:56                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           112           196              1.0           5.88
# 1         1.0            43           263              1.0           0.80
# 2         1.0           255           228              2.0           7.50
# 3         1.0           181           181              1.0           0.90
# 4         1.0            97           188              1.0           2.52
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %% [markdown]
# # QUESTION 3

# %%
df[(df['lpep_pickup_datetime'] >= '2019-10-01') & (df['lpep_dropoff_datetime'] < '2019-11-01') & (df['trip_distance'] <= 1)]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 1            1.0  2019-10-01 00:18:11   2019-10-01 00:22:38
# 3            1.0  2019-10-01 00:37:40   2019-10-01 00:41:49
# 6            1.0  2019-10-01 00:28:09   2019-10-01 00:30:49
# 7            2.0  2019-10-01 00:28:26   2019-10-01 00:32:01
# 18           2.0  2019-10-01 00:30:36   2019-10-01 00:34:30
# ...          ...                  ...                   ...
# 476337       NaN  2019-10-31 22:25:00   2019-10-31 22:33:00
# 476347       NaN  2019-10-31 22:56:00   2019-10-31 23:06:00
# 476350       NaN  2019-10-31 22:47:00   2019-10-31 22:55:00
# 476367       NaN  2019-10-31 22:12:00   2019-10-31 22:17:00
# 476382       NaN  2019-10-31 23:03:00   2019-10-31 23:24:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 1                       N         1.0            43           263
# 3                       N         1.0           181           181
# ...

# %%
df[(df['lpep_pickup_datetime'] >= '2019-10-01') & (df['lpep_dropoff_datetime'] < '2019-11-01') & (df['trip_distance'] > 1) & (df['trip_distance'] <= 3)]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 4            2.0  2019-10-01 00:08:13   2019-10-01 00:17:56
# 5            2.0  2019-10-01 00:35:01   2019-10-01 00:43:40
# 8            2.0  2019-10-01 00:14:01   2019-10-01 00:26:16
# 13           2.0  2019-10-01 00:44:56   2019-10-01 00:51:06
# 14           2.0  2019-10-01 00:55:14   2019-10-01 01:00:49
# ...          ...                  ...                   ...
# 476346       NaN  2019-10-31 22:09:00   2019-10-31 22:20:00
# 476353       NaN  2019-10-31 22:02:00   2019-10-31 22:13:00
# 476359       NaN  2019-10-31 22:44:00   2019-10-31 22:51:00
# 476360       NaN  2019-10-31 22:28:00   2019-10-31 22:36:00
# 476377       NaN  2019-10-31 23:15:00   2019-10-31 23:20:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 4                       N         1.0            97           188
# 5                       N         1.0            65            49
# ...

# %% [markdown]
# # QUESTION 4

# %%
df.sort_values(by='trip_distance')
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 446029       NaN  2019-10-23 00:11:00   2019-10-23 00:27:00
# 446032       NaN  2019-10-23 00:26:00   2019-10-23 00:30:00
# 283179       1.0  2019-10-23 13:00:20   2019-10-23 13:40:51
# 169490       2.0  2019-10-14 04:30:29   2019-10-14 04:32:12
# 169508       2.0  2019-10-14 04:19:00   2019-10-14 04:19:03
# ...          ...                  ...                   ...
# 62935        2.0  2019-10-05 16:42:04   2019-10-05 18:51:30
# 293111       2.0  2019-10-24 10:59:58   2019-10-24 13:11:58
# 317407       2.0  2019-10-26 03:02:39   2019-10-26 07:44:59
# 141174       2.0  2019-10-11 20:34:21   2019-10-11 22:40:41
# 386795       2.0  2019-10-31 23:23:41   2019-11-01 13:01:07
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 446029                NaN         NaN           146            42
# 446032                NaN         NaN            31            20
# ...

# %% [markdown]
# # QUESTION 5

# %%
date_filtered_df = df[(df['lpep_pickup_datetime'] >= '2019-10-18') & (df['lpep_pickup_datetime'] < '2019-10-19')]

# %%
output_df = date_filtered_df.groupby(by='PULocationID').sum()

# %%
output_df.head()
# Out:
#               VendorID                               lpep_pickup_datetime  \
# PULocationID
# 3                 21.0  2019-10-18 08:47:042019-10-18 08:12:552019-10-...
# 4                  0.0  2019-10-18 12:27:002019-10-18 17:32:002019-10-...
# 7               1302.0  2019-10-18 00:25:102019-10-18 00:34:582019-10-...
# 9                 12.0  2019-10-18 02:30:252019-10-18 02:30:252019-10-...
# 10                14.0  2019-10-18 05:13:342019-10-18 06:43:312019-10-...
#
#                                           lpep_dropoff_datetime  \
# PULocationID
# 3             2019-10-18 08:51:202019-10-18 08:36:202019-10-...
# 4             2019-10-18 13:12:002019-10-18 18:36:002019-10-...
# 7             2019-10-18 00:26:542019-10-18 00:45:092019-10-...
# 9             2019-10-18 02:30:382019-10-18 02:30:382019-10-...
# 10            2019-10-18 05:13:452019-10-18 08:04:152019-10-...
#
#                                              store_and_fwd_flag  RatecodeID  \
# PULocationID
# ...

# %%
output_df[output_df['total_amount'] > 13000].sort_values(by='total_amount')
# Out:
#               VendorID                               lpep_pickup_datetime  \
# PULocationID
# 166             1362.0  2019-10-18 00:30:512019-10-18 00:52:322019-10-...
# 75              1941.0  2019-10-18 00:40:322019-10-18 00:25:242019-10-...
# 74              2231.0  2019-10-18 22:58:522019-10-18 00:26:112019-10-...
#
#                                           lpep_dropoff_datetime  \
# PULocationID
# 166           2019-10-18 00:39:352019-10-18 01:33:062019-10-...
# 75            2019-10-18 00:57:472019-10-18 00:27:122019-10-...
# 74            2019-10-19 00:07:302019-10-18 00:38:492019-10-...
#
#                                              store_and_fwd_flag  RatecodeID  \
# PULocationID
# 166           NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...       771.0
# 75            NNNNYNNNNNNYNNNNNYNNNNNNNNNNNNNNNNNNNNNNNNNNNN...      1099.0
# 74            NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...      1280.0
#
# ...

# %% [markdown]
# # QUESTION 6

# %%
filtered = df[(df['lpep_pickup_datetime'] >= '2019-10-01') & (df['lpep_dropoff_datetime'] < '2019-11-01') & (df['PULocationID'] == 74)]
filtered
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 49           2.0  2019-10-01 00:42:36   2019-10-01 00:43:02
# 54           2.0  2019-10-01 00:04:16   2019-10-01 00:09:30
# 63           2.0  2019-10-01 00:27:18   2019-10-01 00:34:21
# 70           2.0  2019-10-01 00:31:22   2019-10-01 00:34:06
# 73           2.0  2019-10-01 00:35:35   2019-10-01 00:51:17
# ...          ...                  ...                   ...
# 475898       NaN  2019-10-31 17:07:00   2019-10-31 18:15:00
# 476027       NaN  2019-10-31 18:14:00   2019-10-31 18:21:00
# 476075       NaN  2019-10-31 18:36:00   2019-10-31 18:55:00
# 476108       NaN  2019-10-31 18:24:00   2019-10-31 18:55:00
# 476340       NaN  2019-10-31 22:08:00   2019-10-31 22:43:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 49                      N         1.0            74            74
# 54                      N         1.0            74           168
# ...

# %%
filtered.sort_values(by='tip_amount')
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 180382       2.0  2019-10-15 09:50:19   2019-10-15 09:54:04
# 476340       NaN  2019-10-31 22:08:00   2019-10-31 22:43:00
# 140173       1.0  2019-10-11 19:14:28   2019-10-11 19:35:32
# 270458       2.0  2019-10-22 11:46:33   2019-10-22 12:18:39
# 270481       2.0  2019-10-22 11:01:36   2019-10-22 11:24:35
# ...          ...                  ...                   ...
# 251261       2.0  2019-10-20 15:14:27   2019-10-20 16:18:12
# 49           2.0  2019-10-01 00:42:36   2019-10-01 00:43:02
# 296026       2.0  2019-10-24 14:35:52   2019-10-24 14:36:32
# 340287       2.0  2019-10-28 06:05:56   2019-10-28 06:09:47
# 308891       2.0  2019-10-25 15:50:05   2019-10-25 16:50:07
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 180382                  N         1.0            74            75
# 476340                NaN         NaN            74            39
# ...
